# %% [markdown]
# ### Import modules & custom utilities

# %%
# Modules
import sys
import numpy as np
import pandas as pd

# Utilities
sys.path.insert(0, '../../utils')
from ipynb.fs.defs.preprocessing import preprocess_dataset
import ipynb.fs.full.vector as uvec
import ipynb.fs.full.pyplot as uplt

# %% [markdown]
# ### Global configurations

# %%
np.set_printoptions(precision = 2)

# %% [markdown]
# ### Import & preprocess data

# %%
dataset, X_train, X_test, y_train, y_test = preprocess_dataset(
    dataset_url = 'position-salaries.csv',
    feature_cols = np.s_[:, 1:-1],
    test_size = 0,
)

# %% [markdown]
# ### Train Decision Tree Regression model

# %%
from sklearn.tree import DecisionTreeRegressor
model = DecisionTreeRegressor(random_state = 0)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %% [markdown]
# ### Predict new results

# %% [markdown]
# Inputs on the same leaf (spilitted area by model) yeild same results

# %%
print(model.predict([[6.5]]))
print(model.predict([[6.0]]))
print(model.predict([[7.0]]))
print(model.predict([[7.3]]))
# Out:
# [150000.]
# [150000.]
# [200000.]
# [200000.]

# %% [markdown]
# ### Visualize the trained model

# %% [markdown]
# Low resolution graph does not illustrate DTR well:

# %%
uplt.visualize_model(model = model, features = X_train, feature_label = 'Position level', results = y_train, result_label = 'Salary', is_resolution_high  = False)

# %%
uplt.visualize_model(model = model, features = X_train, feature_label = 'Position level', results = y_train, result_label = 'Salary')
